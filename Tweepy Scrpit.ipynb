# %%
import os
import tweepy as tw
import pandas as pd
# Out:
# DEBUG: $HOME=C:\Users\rabia
# DEBUG: CONFIGDIR=C:\Users\rabia\.matplotlib
# DEBUG: matplotlib data path: C:\Users\rabia\Anaconda3\lib\site-packages\matplotlib\mpl-data
# DEBUG: loaded rc file C:\Users\rabia\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# DEBUG: matplotlib version 3.1.1
# DEBUG: interactive is False
# DEBUG: platform is win32
# ...

# %%
auth = tw.OAuthHandler("1aoA7eMHPNJHbUqxg6N4layIM", "pO8lgjLcH6LV4TcJBCARHu6LeSnEOetsLOBjfuKsADk3gKpWT3")
auth.set_access_token("181115613-Epb3WTixc41e5H9tFnxPTVO6ShHZHPZfUZIDUXcu", "SMewa7frRlHkkFMghkN1n2Up3zem0Os5lzpm67axB2Sya")
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Define the search term and the date_since date as variables
search_words = "@AmericanAir"
date_since = "2019-12-01"

# %%
# Collect tweets
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(4000)
text = [[tweet.text] for tweet in tweets]
# Out:
# DEBUG: PARAMS: {'q': b'@AmericanAir', 'lang': b'en', 'since': b'2019-12-01'}
# DEBUG: Signing request <PreparedRequest [GET]> using client <Client client_key=1aoA7eMHPNJHbUqxg6N4layIM, client_secret=****, resource_owner_key=181115613-Epb3WTixc41e5H9tFnxPTVO6ShHZHPZfUZIDUXcu, resource_owner_secret=****, signature_method=HMAC-SHA1, signature_type=AUTH_HEADER, callback_uri=None, rsa_key=None, verifier=None, realm=None, encoding=utf-8, decoding=None, nonce=None, timestamp=None>
# DEBUG: Including body in call to sign: False
# DEBUG: Collected params: [('q', '@AmericanAir'), ('lang', 'en'), ('since', '2019-12-01'), ('oauth_nonce', '16065457203933959361576004616'), ('oauth_timestamp', '1576004616'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', '1aoA7eMHPNJHbUqxg6N4layIM'), ('oauth_token', '181115613-Epb3WTixc41e5H9tFnxPTVO6ShHZHPZfUZIDUXcu')]
# ...

# %%
tweet_text = pd.DataFrame(data=text, 
                    columns=['text'])
len(tweet_text)
# Out:
# 4000

# %%
# Save extracted data to a local directory
if os.path.exists('C:/Users/rabia/Desktop/Thinkful/Final/test.csv'):
    os.remove('C:/Users/rabia/Desktop/Thinkful/Final/test.csv')
tweet_text.to_csv('C:/Users/rabia/Desktop/Thinkful/Final/test.csv', encoding='utf-8')
